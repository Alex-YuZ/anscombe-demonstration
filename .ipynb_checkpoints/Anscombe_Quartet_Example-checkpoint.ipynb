# %%
import os
os.chdir("projects_on_GitHub/data_viz/Anscombes_Quartet_Example")

# %%
col_names = ["X1", "Y1", "X2", "Y2", "X3", "Y3","X4", "Y4"]
data = pd.read_excel('anscombes-quartet.xlsx', sheet_name='Sheet1', names = col_names, nrows=11)

# %%
data
# Out:
#     X1     Y1  X2    Y2  X3     Y3  X4     Y4
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89

# %%
d1 = data.loc[:, ['X1', 'Y1']]
d2 = data.loc[:, ['X2', 'Y2']]
d3 = data.loc[:, ['X3', 'Y3']]
d4 = data.loc[:, ['X4', 'Y4']]

# %%
d1.describe()
# Out:
#               X1         Y1
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
d2.describe()
# Out:
#               X2         Y2
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
d3.describe()
# Out:
#               X3         Y3
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
d4.describe()
# Out:
#               X4         Y4
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
plt.subplot(2,2,1)
plt.scatter(data=d1, x='X1', y='Y1')

plt.subplot(2,2,2)
plt.scatter(data=d2, x='X2', y='Y2')

plt.subplot(2,2,3)
plt.scatter(data=d3, x='X3', y='Y3')

plt.subplot(2,2,4)
plt.scatter(data=d4, x='X4', y='Y4');

# %%
d1['X1'].std(), d2['X2'].std(), d3['X3'].std(), d4['X4'].std()
# Out:
# (3.3166247903554, 3.3166247903554, 3.3166247903554, 3.3166247903554)

# %%
d1['Y1'].std(), d2['Y2'].std(), d3['Y3'].std(), d4['Y4'].std()
# Out:
# (2.031568135925815, 2.0316567355016177, 2.030423601123667, 2.0305785113876023)
